# %% [markdown]
# <a href="https://colab.research.google.com/github/mmathen/toolkitten/blob/master/Group_7_Submission%207th%20Dec__M2_NB_MiniProject_2_DeepLabV3%2B_Lungs_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Certification Programme in AI and MLOps
# ## A programme by IISc and TalentSprint
# ### Mini-Project: Lung Segmentation of Chest X-Ray dataset using DeepLabV3+

# %% [markdown]
# ## Learning Objectives:
#
# At the end of the experiment, you will be able to:
#
# - understand, prepare, and visualize the the dataset containing image and corresponding masked image used for segmentation
# - implement DeepLabV3+ architecture
# - create a masked image (prediction)

# %% [markdown]
# ## Introduction
#
# Semantic segmentation is a computer vision task that involves dividing an image into different regions, each of which is labeled with a semantic category. The goal of semantic segmentation is to enable machines to understand the content of an image at a pixel level, by assigning a label to each individual pixel based on the object or region it belongs to.
#
# This technique is widely used in many applications such as self-driving cars, medical image analysis, and object recognition in robotics. It helps to extract meaningful information from images and to understand the relationships between objects and their environment.
#
# The below figure shows how semantic segmentation differs from other algorithms, such as object detection.
#
# <br>
# <img src='https://cdn.iisc.talentsprint.com/AIandMLOps/Images/segmentation_vs_other_algos.jpeg' width=700px>
# <br><br>
#
# Moreover, in contrast to object detection, which detects and localizes objects within an image, semantic segmentation is more precise and detailed. It provides a much more granular understanding of the content of an image, allowing for more advanced and accurate applications.

# %% [markdown]
# ## Dataset
#
# *  The Chest X-Ray dataset is made up of images and segmentated mask from two diffrent sources - Shenzhen and Montgomery dataset
# *  The CXR_png folder consists of Chest X-Rays and the masks folder has the segmented mask
# *  There are 704 images with their masks mapped with each other
#
# <br>
# $\quad$<img src='https://cdn.extras.talentsprint.com/AIandMLOps/Images/semantic_segmentation.png' width=700px>
# <br><br>

# %% [markdown]
# ## Problem Statement
#
# Perfrom the lungs segmentation on Chest X-Ray dataset using DeepLabV3+ model.

# %% [markdown]
# ## Grading = 10 Points

# %%
#@title Download the data
# !wget https://cdn.iisc.talentsprint.com/AIandMLOps/MiniProjects/Datasets/LungSegmentation.zip
# !unzip -qq LungSegmentation.zip
print("Data Downloaded Successfuly!!")
# Out:
# --2024-12-07 03:44:31--  https://cdn.iisc.talentsprint.com/AIandMLOps/MiniProjects/Datasets/LungSegmentation.zip
# Resolving cdn.iisc.talentsprint.com (cdn.iisc.talentsprint.com)... 172.105.52.210
# Connecting to cdn.iisc.talentsprint.com (cdn.iisc.talentsprint.com)|172.105.52.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139904834 (133M) [application/zip]
# Saving to: ‘LungSegmentation.zip’
#
# LungSegmentation.zi 100%[===================>] 133.42M  10.2MB/s    in 14s
#
# 2024-12-07 03:44:46 (9.45 MB/s) - ‘LungSegmentation.zip’ saved [139904834/139904834]
#
# Data Downloaded Successfuly!!

# %% [markdown]
# ### Import required packages

# %%
import os
import cv2
import numpy as np
from glob import glob
from PIL import Image
from scipy.io import loadmat
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ### **PART-A**

# %% [markdown]
# ### Data Visualization (1 point)

# %% [markdown]
# #### Image Visualization
# Visualize one of the Chest X-Ray image and its segmented label image.

# %%
# Visualize an image
from google.colab.patches import cv2_imshow
x = cv2.imread("/content/LungSegmentation/CXR_png/CHNCXR_0001_0.png")


cv2_imshow(x)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# Visualize a semantic part segmentation label image
from google.colab.patches import cv2_imshow
x2 = cv2.imread("/content/LungSegmentation/masks/CHNCXR_0001_0.png")


cv2_imshow(x2)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ### Create a TensorFlow Dataset (1 points)
# Use the image size, batch size, number of classes, and data directory as given in the below code cell.
#
# Hint:
# 1. Find all the image files in the CXR_png and masks subdirectory separately. The resulting list should be sorted in ascending order.
# 2. Create a list of validation image, validation masks, test image, test masks, etc.
# 3. Create a function that reads an image file and returns a preprocessed image tensor.

# %%
IMAGE_SIZE = 512
BATCH_SIZE = 4
NUM_CLASSES = 2
DATA_DIR = "./LungSegmentation"

# Find paths for all the image files in the 'CXR_png' subdirectory of the DATA_DIR directory.
# Sort the list of file paths in ascending order

# Define directories

cxr_dir = "/content/LungSegmentation/CXR_png"
masks_dir = "/content/LungSegmentation/masks"

# Find and sort image files in each directory
cxr_files = sorted(glob(os.path.join(DATA_DIR, cxr_dir, "*.png")))
masks_files = sorted(glob(os.path.join(DATA_DIR, masks_dir, "*.png")))

# Print the results
print("CXR files:", cxr_files)
print("Masks files:", masks_files)

print(f"Total training images: {len(cxr_files)}")
print(f"Total training masks: {len(masks_files)}")

# Find paths for all the mask files in the 'masks' subdirectory of the DATA_DIR directory.
# Sort the list of file paths in ascending order



val_split = 0.15
test_split = 0.15

total_samples = len(cxr_files)
val_samples = int(val_split * total_samples)
test_samples = int(test_split * total_samples)


# # Create a list of validation image files
val_images = cxr_files[:val_samples]
# # Create a list of validation mask files
val_masks = masks_files[:val_samples]


# # Create a list of test image files
test_images = cxr_files[val_samples:val_samples+test_samples]
# # Create a list of test mask files
test_masks = masks_files[val_samples:val_samples+test_samples]


# # Create a list of train image files
train_images = cxr_files[val_samples+test_samples:]
# # Create a list of train mask files
train_masks = masks_files[val_samples+test_samples:]


print(f"Total validation images: {len(val_images)}")
print(f"Total validation masks: {len(val_masks)}")


print(f"Total test images: {len(test_images)}")
print(f"Total test masks: {len(test_masks)}")


print(f"Total training images: {len(train_images)}")
print(f"Total training masks: {len(train_masks)}")
# Out:
# CXR files: ['/content/LungSegmentation/CXR_png/CHNCXR_0001_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0002_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0003_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0004_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0005_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0006_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0007_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0008_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0009_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0010_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0011_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0012_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0013_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0014_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0015_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0016_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0017_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0018_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0019_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0020_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0021_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0022_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0023_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0024_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0026_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0027_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0028_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0029_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0030_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0031_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0032_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0033_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0034_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0035_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0041_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0042_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0043_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0044_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0045_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0046_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0047_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0048_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0049_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0050_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0051_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0052_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0053_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0054_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0055_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0056_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0057_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0058_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0059_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0060_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0061_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0062_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0063_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0064_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0066_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0067_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0068_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0069_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0070_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0071_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0072_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0073_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0074_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0075_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0076_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0077_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0078_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_
ks/CHNCXR_0060_0.png', '/content/LungSegmentation/masks/CHNCXR_0061_0.png', '/content/LungSegmentation/masks/CHNCXR_0062_0.png', '/content/LungSegmentation/masks/CHNCXR_0063_0.png', '/content/LungSegmentation/masks/CHNCXR_0064_0.png', '/content/LungSegmentation/masks/CHNCXR_0066_0.png', '/content/LungSegmentation/masks/CHNCXR_0067_0.png', '/content/LungSegmentation/masks/CHNCXR_0068_0.png', '/content/LungSegmentation/masks/CHNCXR_0069_0.png', '/content/LungSegmentation/masks/CHNCXR_0070_0.png', '/content/LungSegmentation/masks/CHNCXR_0071_0.png', '/content/LungSegmentation/masks/CHNCXR_0072_0.png', '/content/LungSegmentation/masks/CHNCXR_0073_0.png', '/content/LungSegmentation/masks/CHNCXR_0074_0.png', '/content/LungSegmentation/masks/CHNCXR_0075_0.png', '/content/LungSegmentation/masks/CHNCXR_0076_0.png', '/content/LungSegmentation/masks/CHNCXR_0077_0.png', '/content/LungSegmentation/masks/CHNCXR_0078_0.png', '/content/LungSegmentation/masks/CHNCXR_0079_0.png', '/content/LungSegmentation/masks/CHNCXR_0080_0.png', '/content/LungSegmentation/masks/CHNCXR_0081_0.png', '/content/LungSegmentation/masks/CHNCXR_0082_0.png', '/content/L ...
# Total training images: 704
# Total training masks: 704
# Total validation images: 105
# Total validation masks: 105
# Total test images: 105
# Total test masks: 105
# Total training images: 494
# Total training masks: 494

# %%
IMAGE_SIZE = 512
BATCH_SIZE = 4
NUM_CLASSES = 2
DATA_DIR = "./LungSegmentation"

cxr_dir = "/content/LungSegmentation/CXR_png"
masks_dir = "/content/LungSegmentation/masks"

# Find and sort image files in each directory
cxr_files = sorted(glob(os.path.join(DATA_DIR, cxr_dir, "*.png")))
masks_files = sorted(glob(os.path.join(DATA_DIR, masks_dir, "*.png")))

# Print the results
print("CXR files:", cxr_files)
print("Masks files:", masks_files)

print(f"Total training images: {len(cxr_files)}")
print(f"Total training masks: {len(masks_files)}")
# Out:
# CXR files: ['/content/LungSegmentation/CXR_png/CHNCXR_0001_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0002_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0003_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0004_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0005_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0006_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0007_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0008_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0009_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0010_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0011_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0012_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0013_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0014_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0015_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0016_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0017_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0018_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0019_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0020_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0021_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0022_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0023_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0024_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0026_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0027_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0028_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0029_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0030_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0031_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0032_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0033_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0034_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0035_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0041_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0042_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0043_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0044_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0045_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0046_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0047_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0048_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0049_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0050_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0051_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0052_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0053_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0054_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0055_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0056_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0057_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0058_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0059_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0060_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0061_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0062_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0063_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0064_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0066_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0067_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0068_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0069_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0070_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0071_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0072_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0073_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0074_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0075_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0076_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_0077_0.png', '/content/LungSegmentation/CXR_png/CHNCXR_
/LungSegmentation/masks/CHNCXR_0063_0.png', '/content/LungSegmentation/masks/CHNCXR_0064_0.png', '/content/LungSegmentation/masks/CHNCXR_0066_0.png', '/content/LungSegmentation/masks/CHNCXR_0067_0.png', '/content/LungSegmentation/masks/CHNCXR_0068_0.png', '/content/LungSegmentation/masks/CHNCXR_0069_0.png', '/content/LungSegmentation/masks/CHNCXR_0070_0.png', '/content/LungSegmentation/masks/CHNCXR_0071_0.png', '/content/LungSegmentation/masks/CHNCXR_0072_0.png', '/content/LungSegmentation/masks/CHNCXR_0073_0.png', '/content/LungSegmentation/masks/CHNCXR_0074_0.png', '/content/LungSegmentation/masks/CHNCXR_0075_0.png', '/content/LungSegmentation/masks/CHNCXR_0076_0.png', '/content/LungSegmentation/masks/CHNCXR_0077_0.png', '/content/LungSegmentation/masks/CHNCXR_0078_0.png', '/content/LungSegmentation/masks/CHNCXR_0079_0.png', '/content/LungSegmentation/masks/CHNCXR_0080_0.png', '/content/LungSegmentation/masks/CHNCXR_0081_0.png', '/content/LungSegmentation/masks/CHNCXR_0082_0.png', '/content/L ...
# Total training images: 704
# Total training masks: 704

# %%
# Function to read an image file and returns a preprocessed image tensor.
# The mask argument is set to False by default, indicating that it is an image file, not a mask file.

def read_image(image_path, mask=False):
    image = tf.io.read_file(image_path)
    if mask:
        image = tf.image.decode_png(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf.image.convert_image_dtype(image, tf.uint8)
        image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])

    else:
        image_p = tf.image.decode_png(image, channels=3)
        image_p.set_shape([None, None, 3])
        image_p = tf.image.resize(images=image_p, size=[IMAGE_SIZE, IMAGE_SIZE])
        image = tf.keras.applications.resnet50.preprocess_input(image_p, data_format=None)

    return image

image = read_image(train_images[0])

original_image = tf.io.read_file(train_images[1])
original_image_decoded= tf.image.decode_png(original_image)

print(original_image_decoded.shape)
print(image.shape)
# Out:
# (512, 512, 3)
# (512, 512, 3)

# %% [markdown]
# Create a **load_data** function that takes in two arguments, **image_list** and **mask_list**, which are lists of file paths to the images and corresponding masks, respectively. It then reads in the image and mask using the **read_image** function defined earlier. The function returns a tuple of **image** and **mask**.

# %%
def load_data(image_list, mask_list):
    data=[]
    for i in range(len(image_list)):
        image = read_image(image_path=image_list[i])
        mask = read_image(image_path=mask_list[i], mask=True)
        data.append((image, mask))
    return data


train_data = load_data(train_images,train_masks)
test_data = load_data(test_images,test_masks)
val_data = load_data(val_images,val_masks)
print("Train Data: ",len(train_data))
print("Test Data: ",len(test_data))
print("Val Data: ",len(val_data))
# Out:
# Train Data:  494
# Test Data:  105
# Val Data:  105

# %% [markdown]
# Create a **data_generator** function that takes in **image_list** and **mask_list** as arguments.
#
# The function should:
# - create a **tf.data.Dataset** object from the input data
# - map the **load_data** function to each element in the dataset
# - convert the dataset into batches of size **BATCH_SIZE**, drop any incomplete batch at the end of the dataset
# - return the resulting dataset

# %%
# Generate train and validation set

def data_generator(image_list, mask_list):
    dataset = tf.data.Dataset.from_tensor_slices((image_list, mask_list))

    dataset = dataset.map(lambda x, y: load_data([x], [y])[0])
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_dataset = data_generator(train_images,train_masks)
val_dataset = data_generator(val_images,val_masks)
test_dataset = data_generator(test_images,test_masks)


print("Train Dataset: ",train_dataset)
print("Val Dataset: ",val_dataset)
print("Test Dataset: ",test_dataset)
# Out:
# Train Dataset:  <_BatchDataset element_spec=(TensorSpec(shape=(4, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 512, 512, 1), dtype=tf.float32, name=None))>
# Val Dataset:  <_BatchDataset element_spec=(TensorSpec(shape=(4, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 512, 512, 1), dtype=tf.float32, name=None))>
# Test Dataset:  <_BatchDataset element_spec=(TensorSpec(shape=(4, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 512, 512, 1), dtype=tf.float32, name=None))>

# %% [markdown]
# Check the total images for train and validation.

# %%
# YOUR CODE HERE
print(f"Number of train : {len(train_images)}")
print(f"Number of validation : {len(val_images)}")
print(f"Number of test : {len(test_images)}")
# Out:
# Number of train : 494
# Number of validation : 105
# Number of test : 105

# %% [markdown]
# Check the number of batches formed in train and validation set.

# %%
# YOUR CODE HERE
print(f"Number of train batches: {len(list(train_dataset))}")
print(f"Number of validation batches: {len(list(val_dataset))}")
print(f"Number of test batches: {len(list(test_dataset))}")
# Out:
# Number of train batches: 123
# Number of validation batches: 26
# Number of test batches: 26

# %% [markdown]
# Now, we have created our TensorFlow Dataset. Further, let us try to understand the DeepLabV3+ model.

# %% [markdown]
# ### **PART-B**

# %% [markdown]
# ### Building the DeepLabV3+ model

# %% [markdown]
# Downsampling is widely adopted in deep convolutional neural networks (CNN) for reducing memory consumption while preserving the transformation invariance to some degree.
#
# Multiple downsampling of a CNN will lead the feature map resolution to become smaller, resulting in lower prediction accuracy and loss of boundary information in semantic segmentation.
#
# DeepLabv3+ helps in solving these issues by including **atrous convolutions**. They aggregate context around a feature which helps in segmenting it better.
#
# <br>
#
# #### **Atrous Convolution/Dilated Convolution**
#
# It is a tool for refining the effective field of view of the convolution. It modifies the field of view using a parameter termed ***atrous rate*** or ***dilation rate***.
#
# With dilated convolution, as we go deeper in the network, we can keep the stride constant but with larger field-of-view without increasing the number of parameters or the amount of computation. It also enables larger output feature maps, which is useful for semantic segmentation.
#
# In the below figure, Atrous/Dilated Convolution has wider field of view with same number of parameters as Normal convolution.
#
# <br>
# <img src="https://cdn.iisc.talentsprint.com/AIandMLOps/Images/Dilated_Conv.jpg" width=500px>
# <br><br>
#
#
#
# #### **DeepLabv3+**
#
# Earlier version, DeepLabv3 has a problem of consuming too much time to process high-resolution images. DeepLabv3+ is a semantic segmentation architecture that improves upon DeepLabv3 with several improvements, such as adding an effective decoder module to refine the segmentation results.
#
# The below figure shows the typical architecture of DeepLabv3+. The encoder module processes multiscale contextual information by applying dilated/atrous convolution at multiple scales, while the decoder module refines the segmentation results along object boundaries.
#
# <br>
# <img src="https://cdn.iisc.talentsprint.com/AIandMLOps/Images/deeplabv3_plus_model.png" width=1000px>
# <br><br>
#
# Deeplabv3+ employs Aligned Xception network as its main feature extractor (encoder), although with substantial modifications. Depth-wise separable convolution replaces all max pooling procedures.
#
# In Model Playground, we can select feature extraction (encoding) network to use as either **Resnet** or EfficientNet.
#
# The reason for using **Dilated Spatial Pyramid Pooling** is that it was shown that as the sampling rate becomes larger, the number of valid filter weights (i.e., weights that are applied to the valid feature region, instead of padded zeros) becomes smaller.

# %% [markdown]
# ### Create the model (5 points)
# First, create different functions  to implement DeepLabV3+ architecture.

# %% [markdown]
# Create a function, **convolution_block()**, to add a convolution layer, a BatchNormalization layer, and apply ReLu activation in one go.

# %%
# YOUR CODE HERE

# %% [markdown]
# Create another function to perform **Dilated Spatial Pyramid Pooling**. Use above function to add different convolution blocks.

# %%
# YOUR CODE HERE

# %% [markdown]
# The encoder features are first bilinearly upsampled by a factor 4, and then concatenated with the corresponding low-level features from the network backbone that have the same spatial resolution. Here, we use a **ResNet50** pretrained on ImageNet as the backbone model, and we use
# the low-level features from the `conv4_block6_2_relu` block of the backbone.
#
# ##### Exploring ResNet-50 architecture before using it.

# %%
res_input = keras.Input(shape=(128, 128, 3))
resnet50 = keras.applications.ResNet50(weights="imagenet", include_top=False, input_tensor = res_input)

# Layers present in ResNet-50 network
resnet50.summary()

# %% [markdown]
# From the above layers,
#
# - Use the low-level features from the `conv2_block3_2_relu` layer of the ResNet-50 network to fead in Decoder.
#
# - Use the features from the `conv4_block6_2_relu` layer of the ResNet-50 to fead in Dilated Spatial Pyramid Pooling module.

# %% [markdown]
# #### Create Encoder
# Create a function to implement the architecture for Encoder block. Use **ResNet50** pretrained on ImageNet as the backbone network. Use the features from the **conv4_block6_2_relu** layer of the backbone to fead in Dilated Spatial Pyramid Pooling module. Then return the backbone network along with encoder output.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Create Decoder
#
# Create a function to implement the architecture for Decoder block. The encoder features are first bilinearly upsampled by a factor 4, and then concatenated with the corresponding low-level features (the **conv2_block3_2_relu** layer) from the network backbone that have the same spatial resolution.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Building full architecture of the Model
#
# Write a function that combines the encoder and decoder functions defined above to create & implement a complete  DeepLabV3+ architecture.

# %%
# YOUR CODE HERE

# %%
# Create model

# %% [markdown]
# ### Training (1 point)
#
# We train the model using sparse categorical crossentropy as the loss function, and
# Adam as the optimizer.

# %% [markdown]
# ##### Compile model

# %%
# YOUR CODE HERE

# %% [markdown]
# ##### Model Training

# %%
# YOUR CODE HERE

# %% [markdown]
# We can plot the training and validation loss to see how the training went. This should show generally decreasing values per epoch.

# %% [markdown]
# #####  Learning curve from model history (1 point)

# %%
# Function to plot learning curves
# YOUR CODE HERE

# %%
# Display learning curves
# YOUR CODE HERE

# %% [markdown]
# ### Visualize Predictions (1 points)

# %%
# Inference from model
# YOUR CODE HERE

# %% [markdown]
# #### Plot the predictions

# %%
# YOUR CODE HERE
